# %%
# %sql
--CREATE OR REPLACE TABLE workspace.bigquery_db_cohort_db.gold_retention_rate AS

WITH 
customer_groups AS (
  SELECT 
      customer_id,
      first_order_date,
      second_order_date,
      -- monthly cohort
      DATE_TRUNC('month', first_order_date)::DATE AS cohort_month, 
      -- difference in months (30, 60, 90 days) between first and second purchase
      DATEDIFF(second_order_date, first_order_date) AS days_to_second

  FROM workspace.bigquery_db_cohort_db.silver_cohort_analysis

)


SELECT 
    cohort_month,
    
    --percentages of customers who made a second purchase within 1,2 or 3 month
    ROUND(100.0 * SUM(CASE WHEN second_order_date IS NOT NULL AND days_to_second <= 30 THEN 1 ELSE 0 END) / COUNT(*),2) AS retention_rate_1m
    ROUND(100.0 * SUM(CASE WHEN second_order_date IS NOT NULL AND days_to_second <= 60 THEN 1 ELSE 0 END) / COUNT(*),2) AS retention_rate_2m
    ROUND(100.0 * SUM(CASE WHEN second_order_date IS NOT NULL AND days_to_second <= 90 THEN 1 ELSE 0 END) / COUNT(*),2) AS retention_rate_3m

FROM customer_groups
GROUP BY cohort_month
ORDER BY cohort_month;
